# %%
import sys
import os

# Ajoute le dossier src au chemin d'importation
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

from src.utils.generate import *

# %%
def main():
    """Génère toutes les visualisations."""
    section("GÉNÉRATION DE TOUTES LES VISUALISATIONS")
    
    print("1-  Diagramme d'architecture...")
    generate_architecture_diagram()
    
    print("2-  Tableau de résultats...")
    generate_comparison_table_image()
    
    print("3-  Comparaison des courbes d'apprentissage...")
    generate_learning_comparison()
    
    print("4-  Comparaison Gantt...")
    generate_gantt_comparison()
    
    print("5-  Radar de performance...")
    generate_performance_radar()
    
if __name__ == "__main__":
    main()
# Out:
# ...
# GÉNÉRATION DE TOUTES LES VISUALISATIONS
# ...
#
# 1-  Diagramme d'architecture...
# [2025-11-13 13:57:21] 💾 Architecture diagram saved : d:\Workspace\Job_Shop_Problem_Claude\results\plots\architecture_diagram.png
# 2-  Tableau de résultats...
# [2025-11-13 13:57:21] 💾 Results table saved: : d:\Workspace\Job_Shop_Problem_Claude\results\plots\results_table.png
# 3-  Comparaison des courbes d'apprentissage...
# [2025-11-13 13:57:21] 💾 Learning comparison saved : d:\Workspace\Job_Shop_Problem_Claude\results\plots\learning_comparison.png
# 4-  Comparaison Gantt...
#  [2025-11-13 13:57:21] 💬 Device utilisé: cpu
#
#  ✅ Modèle Deep DQN chargé : d:\Workspace\Job_Shop_Problem_Claude\results\models\deep_dqn_FT06.pth
# [2025-11-13 13:57:23] 💾 Comparaison sauvegardée : d:\Workspace\Job_Shop_Problem_Claude\results\plots\gantt_comparison.png
# [2025-11-13 13:57:23] 💾 Gantt comparison saved: : d:\Workspace\Job_Shop_Problem_Claude\results\plots\gantt_comparison.png
# 5-  Radar de performance...
# ...
